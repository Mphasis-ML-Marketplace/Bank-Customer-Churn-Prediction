# %% [markdown]
# ## Ticket Classification Prediction
# The solution handles the misclassification of tickets using multifactor AI/ML based classification model. The As-Is classification scheme leads to higher MTTR(Mean Time to Resolution) and low FCR (First Call Resolution) due to misclassification of tickets. The current scheme handles these problems by automating classification of tickets using classification models. The solution considers factors such as ticket impact, urgency, priority along with ticket description and ticket categories.
#
# ### Contents
#
# 1. [Set up the environment](#Set-up-the-environment)
# 1. [Usage Instructions](#Usage-Instructions)
# 1. [Upload the data for training](#Upload-the-data-for-training)
# 1. [Run Training Job](#Run-Training-Job)
# 1. [Live Inference Endpoint](#Live Inference)
# 1. [Batch Transform Job](#Batch-Transform-Job)
# 1. [Output Interpretation](#Output-Interpretation)
#
#
#
# <img src="images/Flow_diagram.JPG">

# %% [markdown]
# ### Prerequisite
#
# To run this algorithm you need to have access to the following AWS Services:
# - Access to AWS SageMaker and the model package.
# - An S3 bucket to specify input/output.
# - Role for AWS SageMaker to access input/output from S3.

# %% [markdown]
# ### Input format
# #### Input:
# Name of the file: <b>train.csv</b><br>
# This file contains historical incidents that have been resolved. The solution uses the following incident specific inputs to derive specific productivity measures such as efficiency, experience and workload management across incident types for incident managers to make the predictions.<br><br>
#
# </ul>
# <li>  ID: Unique identifier for the request- alphanumeric e.g. INC0001029696</li>
# <li> Reported_Day: The day of the week in number (Preferred format: 1-7)</li>
#
# <li> prod_cat: First level category for requests e.g. Miscellaneous_Instance_Database_SQL Server Database</li>
# <li> Country: Country of origin of request, Preferred format: USA)</li>
# <li> Detailed_Description: Free Text Describing the problem in users works</li>
# <li> Priority: Status of the request e.g. Low/Medium/High</li>
# <li> Impact: High/Medium/Low
# </ul><br>
# NOTE:
# </ul>
# <li>Not all requests are mandatory. Optional Fields :Prod_Cat, Detailed_Description,prod_cat</li>
#
# </ul>

# %% [markdown]
# ## Set up the environment
# Here we specify a bucket to use and the role that will be used for working with SageMaker.

# %%
# S3 prefix
prefix = 'churn-telecom'

# Define IAM role
import boto3
import re

import os
import numpy as np
import pandas as pd
from sagemaker import get_execution_role

role = get_execution_role()

# %% [markdown]
# ## Create the session
# The session remembers our connection parameters to SageMaker. We'll use it to perform all of our SageMaker operations.

# %%
import sagemaker as sage
from time import gmtime, strftime

sess = sage.Session()

# %% [markdown]
# ## Upload the data for training
# When training large models with huge amounts of data, you'll typically use big data tools, like Amazon Athena, AWS Glue, or Amazon EMR, to create your data in S3. For the purposes of this example, we're using classification dataset, which we have included.
#
# We can use use the tools provided by the SageMaker Python SDK to upload the data to a default bucket.

# %%
data_location= 's3://mphasis-marketplace/churn-prediction-bank/input/train.csv'

# %% [markdown]
# ## Create an estimator and fit the model
# In order to use SageMaker to fit our algorithm, we'll create an Estimator that defines how to use the container to train. This includes the configuration we need to invoke SageMaker training:
# - The container name. This is constructed as in the shell commands above.
# - The role. As defined above.
# - The instance count which is the number of machines to use for training.
# - The instance type which is the type of machine to use for training.
# - The output path determines where the model artifact will be written.
# - The session is the SageMaker session object that we defined above
#
# Then we use fit() on the estimator to train against the data that we uploaded above.

# %%
account = sess.boto_session.client('sts').get_caller_identity()['Account']
region = sess.boto_session.region_name
image = '{}.dkr.ecr.{}.amazonaws.com/bank-pycaret-churn:latest'.format(account, region)

tree = sage.estimator.Estimator(image,
                       role, 3, 'ml.c4.2xlarge',
                      output_path="s3://{}/output".format(sess.default_bucket()),
                       sagemaker_session=sess)

tree.fit(data_location)
# Out:
# 2021-04-20 13:33:55 Starting - Starting the training job...
# 2021-04-20 13:34:19 Starting - Launching requested ML instancesProfilerReport-1618925635: InProgress
# ......
# 2021-04-20 13:35:19 Starting - Preparing the instances for training......
# 2021-04-20 13:36:19 Downloading - Downloading input data
# 2021-04-20 13:36:19 Training - Downloading the training image.....
# 2021-04-20 13:37:19 Training - Training image download completed. Training in progress.Starting the training.
# (10000, 13)
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              13:37:08
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     13:37:08
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     13:37:08
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            13:37:08
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            13:37:08
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Setup Succesfully Completed!
# #033[2K#015#033[2K#015<pandas.io.formats.style.Styler object at 0x7f21407ff5c0>
# Starting the training.
# (10000, 13)
# IntProgress(value=0, description='Processing: ', max=69)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Starting the training.
# (10000, 13)
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              13:37:12
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     13:37:12
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     13:37:12
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            13:37:12
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            13:37:12
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Setup Succesfully Completed!
# #033[2K#015#033[2K#015<pandas.io.formats.style.Styler object at 0x7f921c7f6550>
# Setup Succesfully Completed!
# #033[2K#015#033[2K#015<pandas.io.formats.style.Styler object at 0x7fd9797ae668>
# IntProgress(value=0, description='Processing: ', max=69)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              13:37:14
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           13:37:14
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           13:37:14
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:14
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:14
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:14
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:14
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:14
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:14
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:14
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:14
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:14
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:14
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <pandas.io.formats.style.Styler object at 0x7f2140661d68>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:11
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:11
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:11
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:11
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:11
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:11
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:11
# Status     . . . . . . . . . . . . . . . . . .         Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:11
# Status     . . . . . . . . . . . . . . . . . .         Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:11
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:11
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
# IntProgress(value=0, description='Processing: ', max=69)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              13:37:15
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           13:37:15
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           13:37:15
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:15
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:15
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:15
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:15
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:15
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:15
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:15
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:15
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:15
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:15
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <pandas.io.formats.style.Styler object at 0x7f2181015e48>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .       Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .       Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .          Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .          Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .          Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .          Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .      Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .      Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .       Naive Bayes
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .       Naive Bayes
# <pandas.io.formats.style.Styler object at 0x7f2140818668>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  13:37:11
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  13:37:11
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  13:37:11
# Status     . . . . . . . . . . . . . . . . . .       Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  13:37:11
# Status     . . . . . . . . . . . . . . . . . .       Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  13:37:11
# Status     . . . . . . . . . . . . . . . . . .       Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  13:37:11
# Status     . . . . . . . . . . . . . . . . . .       Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  13:37:11
# Status     . . . . . . . . . . . . . . . . . .           Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  13:37:11
# Status     . . . . . . . . . . . . . . . . . .           Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  13:37:11
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  13:37:11
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Decision Tree Classifier
# <pandas.io.formats.style.Styler object at 0x7f922c3e19b0>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:14
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:14
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:14
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:14
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:14
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:14
# Status     . . . . . . . . . . . . . . . . . .     Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:14
# Status     . . . . . . . . . . . . . . . . . .         Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:14
# Status     . . . . . . . . . . . . . . . . . .         Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:14
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                13:37:14
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
# <pandas.io.formats.style.Styler object at 0x7f21810320f0>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .      Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  SVM - Linear Kernel
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# <pandas.io.formats.style.Styler object at 0x7f217d51f0b8>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:37:11
# Status     . . . . . . . . . . . . . . . . . .  Selecting Estimator
# Estimator  . . . . . . . . . . . . . . . . . .     Ridge Classifier
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          13:37:11
# Status     . . . . . . . . . . . . . . . . . .   Initializing CV
# Estimator  . . . . . . . . . . . . . . . . . .  Ridge Classifier
#
# ...
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:14
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:14
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:14
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:14
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:14
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:14
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:14
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:14
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:14
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:14
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:14
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:14
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
# #033[2K#015#033[2K#015<pandas.io.formats.style.Styler object at 0x7f92097367f0>
# Transformation Pipeline and Model Succesfully Saved
# rf model saved
# files under /opt/ml/model  ['/opt/ml/model/model.pkl']
# model saved
# total time taken using multiprocessing is -  18.033119322
# training complete
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:37:15
# Status                       Creating Logs
# Estimator  Light Gradient Boosting Machine
# #033[2K#015#033[2K#015<pandas.io.formats.style.Styler object at 0x7fd97bbdb400>
# Transformation Pipeline and Model Succesfully Saved
# rf model saved
# files under /opt/ml/model  ['/opt/ml/model/model.pkl']
# model saved
# total time taken using multiprocessing is -  20.366647335000003
# training complete
#
# 2021-04-20 13:38:19 Completed - Training job completed
# Training seconds: 354
# Billable seconds: 354

# %% [markdown]
# ## Hosting your model
# You can use a trained model to get real time predictions using HTTP endpoint. Follow these steps to walk you through the process.

# %%
training_job_name = tree.latest_training_job.name
attached_tree = sage.estimator.Estimator.attach(training_job_name)
# Out:
# 2021-04-20 13:38:40 Starting - Preparing the instances for training
# 2021-04-20 13:38:40 Downloading - Downloading input data
# 2021-04-20 13:38:40 Training - Training image download completed. Training in progress.
# 2021-04-20 13:38:40 Uploading - Uploading generated training model
# 2021-04-20 13:38:40 Completed - Training job completed

# %% [markdown]
# ### Deploy the model
# Deploying the model to SageMaker hosting just requires a deploy call on the fitted model. This call takes an instance count, instance type, and optionally serializer and deserializer functions. These are used when the resulting predictor is created on the endpoint.

# %%
from sagemaker.predictor import csv_serializer
predictor = attached_tree.deploy(4, 'ml.m4.xlarge', serializer=csv_serializer,endpoint_name='churn-bank')
# Out:
# -------------!

# %% [markdown]
# ## Choose some data and use it for a prediction

# %%
test_data  = 's3://mphasis-marketplace/churn-prediction-bank/input/test.csv'

data = pd.read_csv(test_data,encoding='ISO-8859–1',header=None)
data
# Out:
#           0           1            2          3       4    5       6   \
# 0  RowNumber  CustomerId  CreditScore  Geography  Gender  Age  Tenure
# 1          1    15634602          619     France  Female   42       2
# 2          2    15647311          608      Spain  Female   41       1
# 3          3    15619304          502     France  Female   42       8
# 4          4    15701354          699     France  Female   39       1
# 5          5    15737888          850      Spain  Female   43       2
# 6          6    15574012          645      Spain    Male   44       8
#
#           7              8          9               10               11
# 0    Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 1          0              1          1               1        101348.88
# 2   83807.86              1          0               1        112542.58
# 3   159660.8              3          1               0        113931.57
# 4          0              2          0               0         93826.63
# 5  125510.82              1          1               1          79084.1
# 6  113755.78              2          1               0        149756.71

# %%
predictions = predictor.predict(data.values).decode('utf-8')
# Out:
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
print(predictions)
# Out:
# RowNumber,CustomerId,CreditScore,Geography,Gender,Age,Tenure,Balance,NumOfProducts,HasCrCard,IsActiveMember,EstimatedSalary,Label,Score
# 1,15634602,619,France,Female,42,2,0.0,1,1,1,101348.88,1,0.5572
# 2,15647311,608,Spain,Female,41,1,83807.86,1,0,1,112542.58,0,0.8611
# 3,15619304,502,France,Female,42,8,159660.8,3,1,0,113931.57,1,0.5508
# 4,15701354,699,France,Female,39,1,0.0,2,0,0,93826.63,0,0.8953
# 5,15737888,850,Spain,Female,43,2,125510.82,1,1,1,79084.1,0,0.9496
# 6,15574012,645,Spain,Male,44,8,113755.78,2,1,0,149756.71,0,0.5858

# %% [markdown]
# ### Output
#
# Output files contains column predicted Group, which has the predicted class

# %%
transform_output_folder = "batch-transform-output"
output_path="s3://{}/{}".format(sess.default_bucket(), transform_output_folder)

transformer = tree.transformer(instance_count=1,
                               instance_type='ml.m4.xlarge',
                               output_path=output_path)

# %%
transformer.transform(test_data, content_type='text/csv')
transformer.wait()
print("Batch Transform output saved to " + transformer.output_path)
# Out:
# ...........................Starting the inference server with 4 workers.
# [2021-04-20 13:51:51 +0000] [12] [INFO] Starting gunicorn 20.1.0
# [2021-04-20 13:51:51 +0000] [12] [INFO] Listening at: unix:/tmp/gunicorn.sock (12)
# [2021-04-20 13:51:51 +0000] [12] [INFO] Using worker: gevent
# [2021-04-20 13:51:51 +0000] [16] [INFO] Booting worker with pid: 16
# [2021-04-20 13:51:52 +0000] [17] [INFO] Booting worker with pid: 17
# [2021-04-20 13:51:52 +0000] [18] [INFO] Booting worker with pid: 18
# [2021-04-20 13:51:52 +0000] [20] [INFO] Booting worker with pid: 20
# Transformation Pipeline and Model Successfully Loaded
# 169.254.255.130 - - [20/Apr/2021:13:52:00 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [20/Apr/2021:13:52:00 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# 169.254.255.130 - - [20/Apr/2021:13:52:00 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [20/Apr/2021:13:52:00 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Transformation Pipeline and Model Successfully Loaded
# 2021-04-20T13:52:00.803:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# 169.254.255.130 - - [20/Apr/2021:13:52:01 +0000] "POST /invocations HTTP/1.1" 200 528 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [20/Apr/2021:13:52:01 +0000] "POST /invocations HTTP/1.1" 200 528 "-" "Go-http-client/1.1"
#
# Starting the inference server with 4 workers.
# [2021-04-20 13:51:51 +0000] [12] [INFO] Starting gunicorn 20.1.0
# [2021-04-20 13:51:51 +0000] [12] [INFO] Listening at: unix:/tmp/gunicorn.sock (12)
# Starting the inference server with 4 workers.
# [2021-04-20 13:51:51 +0000] [12] [INFO] Starting gunicorn 20.1.0
# [2021-04-20 13:51:51 +0000] [12] [INFO] Listening at: unix:/tmp/gunicorn.sock (12)
# [2021-04-20 13:51:51 +0000] [12] [INFO] Using worker: gevent
# [2021-04-20 13:51:51 +0000] [16] [INFO] Booting worker with pid: 16
# [2021-04-20 13:51:52 +0000] [17] [INFO] Booting worker with pid: 17
# [2021-04-20 13:51:52 +0000] [18] [INFO] Booting worker with pid: 18
# [2021-04-20 13:51:52 +0000] [20] [INFO] Booting worker with pid: 20
# [2021-04-20 13:51:51 +0000] [12] [INFO] Using worker: gevent
# [2021-04-20 13:51:51 +0000] [16] [INFO] Booting worker with pid: 16
# [2021-04-20 13:51:52 +0000] [17] [INFO] Booting worker with pid: 17
# [2021-04-20 13:51:52 +0000] [18] [INFO] Booting worker with pid: 18
# [2021-04-20 13:51:52 +0000] [20] [INFO] Booting worker with pid: 20
# Transformation Pipeline and Model Successfully Loaded
# 169.254.255.130 - - [20/Apr/2021:13:52:00 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [20/Apr/2021:13:52:00 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# 169.254.255.130 - - [20/Apr/2021:13:52:00 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [20/Apr/2021:13:52:00 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Transformation Pipeline and Model Successfully Loaded
# 2021-04-20T13:52:00.803:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# 169.254.255.130 - - [20/Apr/2021:13:52:01 +0000] "POST /invocations HTTP/1.1" 200 528 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [20/Apr/2021:13:52:01 +0000] "POST /invocations HTTP/1.1" 200 528 "-" "Go-http-client/1.1"
# Batch Transform output saved to s3://sagemaker-us-east-2-786796469737/batch-transform-output

# %% [markdown]
# #### Inspect the Batch Transform Output in S3

# %%
from urllib.parse import urlparse

parsed_url = urlparse(transformer.output_path)
bucket_name = parsed_url.netloc
file_key = '{}/{}.out'.format(parsed_url.path[1:], "test.csv")



s3_client = sess.boto_session.client('s3')

response = s3_client.get_object(Bucket = sess.default_bucket(), Key = file_key)
response_bytes = response['Body'].read().decode('utf-8')
print(response_bytes)
# Out:
# RowNumber,CustomerId,CreditScore,Geography,Gender,Age,Tenure,Balance,NumOfProducts,HasCrCard,IsActiveMember,EstimatedSalary,Label,Score
# 1,15634602,619,France,Female,42,2,0.0,1,1,1,101348.88,1,0.5572
# 2,15647311,608,Spain,Female,41,1,83807.86,1,0,1,112542.58,0,0.8611
# 3,15619304,502,France,Female,42,8,159660.8,3,1,0,113931.57,1,0.5508
# 4,15701354,699,France,Female,39,1,0.0,2,0,0,93826.63,0,0.8953
# 5,15737888,850,Spain,Female,43,2,125510.82,1,1,1,79084.1,0,0.9496
# 6,15574012,645,Spain,Male,44,8,113755.78,2,1,0,149756.71,0,0.5858

# %% [markdown]
# ### View Output
# Lets read results of above transform job from s3 files and print output

# %%
s3_client = sess.boto_session.client('s3')
s3_client.download_file(sess.default_bucket(), "{}/test.csv.out".format(transform_output_folder), '/tmp/test.csv.out')
with open('/tmp/test.csv.out') as f:
    results = f.readlines() 
##print("Transform results: \n{}".format(''.join(results)))
string_final = ''.join(results)

print(string_final)

with open("Output.txt", "w") as text_file:
    text_file.write(string_final)
# Out:
# RowNumber,CustomerId,CreditScore,Geography,Gender,Age,Tenure,Balance,NumOfProducts,HasCrCard,IsActiveMember,EstimatedSalary,Label,Score
# 1,15634602,619,France,Female,42,2,0.0,1,1,1,101348.88,1,0.5572
# 2,15647311,608,Spain,Female,41,1,83807.86,1,0,1,112542.58,0,0.8611
# 3,15619304,502,France,Female,42,8,159660.8,3,1,0,113931.57,1,0.5508
# 4,15701354,699,France,Female,39,1,0.0,2,0,0,93826.63,0,0.8953
# 5,15737888,850,Spain,Female,43,2,125510.82,1,1,1,79084.1,0,0.9496
# 6,15574012,645,Spain,Male,44,8,113755.78,2,1,0,149756.71,0,0.5858
